# %%
import pandas as pd

# %%
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/474623347.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs = pd.read_csv('Data/2017_2018_NHL_PbP_Logs.csv')

# %%
logs = pd.read_csv('Data/2017_2018_NHL_PbP_Logs.csv')
logs.columns = logs.iloc[0]
logs = logs.drop(0)
logs
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/3782091614.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs = pd.read_csv('Data/2017_2018_NHL_PbP_Logs.csv')
# 0               BIGDATABALL\nDATASET BIGDATABALL\nGAME ID     DATE  \
# 1       NHL 2017-2018 Regular Season        43012-TOR@WPG  10/4/17
# 2       NHL 2017-2018 Regular Season        43012-TOR@WPG  10/4/17
# 3       NHL 2017-2018 Regular Season        43012-TOR@WPG  10/4/17
# 4       NHL 2017-2018 Regular Season        43012-TOR@WPG  10/4/17
# 5       NHL 2017-2018 Regular Season        43012-TOR@WPG  10/4/17
# ...                              ...                  ...      ...
# 434875             NHL 2018 Playoffs        43258-WSH@VGS   6/7/18
# 434876             NHL 2018 Playoffs        43258-WSH@VGS   6/7/18
# 434877             NHL 2018 Playoffs        43258-WSH@VGS   6/7/18
# ...

# %%
column_names =['Dataset','Game_ID','Date','Away','Home',
               'Score_Away','Score_Home',
               'Period','Time_Remaining','Time_Elapsed',
               'PlayID','Play_Length','Play_Type','Play_SubType','Zone',
               'Play_Team','Play_Agent1','Play_Agent2','Play_Agent3',
               'Shot_Distance','X_Coordinate','Y_Coordinate',
               'Description',
               'Strength',
               'Away_Strength','Away_Agent1','Away_Agent2','Away_Agent3','Away_Agent4','Away_Agent5','Away_Agent6','Away_Goalie',
               'Home_Strength','Home_Agent1','Home_Agent2','Home_Agent3','Home_Agent4','Home_Agent5','Home_Agent6','Home_Goalie' 
               ]
logs.columns = column_names

# %%
logs['Game_ID'].value_counts()
# Out:
# Game_ID
# 43203-LA@VGS     567
# 43218-SJ@VGS     525
# 43219-WPG@NSH    488
# 43205-CBJ@WSH    452
# 43236-WPG@VGS    426
#                 ...
# 43197-DAL@LA     248
# 43114-VAN@MIN    245
# 43139-NYI@BUF    235
# 43104-BUF@MIN    234
# 43053-PHI@MIN    212
# Name: count, Length: 1355, dtype: int64

# %%
logs2 = pd.read_csv('Data/2018_2019_NHL_PbP_Logs.csv')
logs2.columns = logs2.iloc[0]
logs2 = logs2.drop(0)
logs2.columns = column_names
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/907746190.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs2 = pd.read_csv('Data/2018_2019_NHL_PbP_Logs.csv')

# %%
all_logs = pd.concat([logs,logs2],axis=0)

# %%
logs2 = pd.read_csv('Data/2019_2020_NHL_PbP_Logs.csv')
logs2.columns = logs2.iloc[0]
logs2 = logs2.drop(0)
logs2.columns = column_names
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/3995878217.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs2 = pd.read_csv('Data/2019_2020_NHL_PbP_Logs.csv')

# %%
all_logs = pd.concat([all_logs,logs2],axis=0)

# %%
logs2 = pd.read_csv('Data/2020_2021_NHL_PbP_Logs.csv')
logs2.columns = logs2.iloc[0]
logs2 = logs2.drop(0)
logs2.columns = column_names
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/2944338400.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs2 = pd.read_csv('Data/2020_2021_NHL_PbP_Logs.csv')

# %%
all_logs = pd.concat([all_logs,logs2],axis=0)

# %%
logs2 = pd.read_csv('Data/2021_2022_NHL_PbP_Logs.csv')
#logs2.columns = logs2.iloc[0]
#logs2 = logs2.drop(0)
#logs2.columns = column_names
# Out:
# /var/folders/7r/r2s5qqq505q1dy3w3pxj6rnc0000gn/T/ipykernel_60051/3244691538.py:1: DtypeWarning: Columns (5,6,7,10,19,20,21,24,32,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   logs2 = pd.read_csv('Data/2021_2022_NHL_PbP_Logs.csv')

# %%
logs2
# Out:
#                          GAME DETAIL            Unnamed: 1 Unnamed: 2  \
# 0               BIGDATABALL\nDATASET  BIGDATABALL\nGAME ID       DATE
# 1       NHL 2021-2022 Regular Season          44481-PIT@TB   10/12/21
# 2       NHL 2021-2022 Regular Season          44481-PIT@TB   10/12/21
# 3       NHL 2021-2022 Regular Season          44481-PIT@TB   10/12/21
# 4       NHL 2021-2022 Regular Season          44481-PIT@TB   10/12/21
# ...                              ...                   ...        ...
# 436611             NHL 2022 Playoffs          44738-COL@TB    6/26/22
# 436612             NHL 2022 Playoffs          44738-COL@TB    6/26/22
# 436613             NHL 2022 Playoffs          44738-COL@TB    6/26/22
# 436614             NHL 2022 Playoffs          44738-COL@TB    6/26/22
# 436615             NHL 2022 Playoffs          44738-COL@TB    6/26/22
#
#                  Unnamed: 3           Unnamed: 4              Unnamed: 5  \
# ...
