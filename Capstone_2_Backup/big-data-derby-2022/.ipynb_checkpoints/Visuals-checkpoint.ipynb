# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.animation as animation

# %%
from shapely.geometry import Polygon, box, LineString, Point
from shapely.geometry import MultiPolygon,MultiLineString,MultiPoint

# %%
# %matplotlib widget

# %%
entries=pd.read_csv('nyra_start_table_new.csv')
races=pd.read_csv('nyra_race_table.csv')
tracking=pd.read_csv('nyra_tracking_table.csv')
tracking.program_number=tracking.program_number.str.replace(' ','-')

# %%
def run(data):
    # update the data
    t=data
    y = np.random.uniform(0,10)
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
    line.set_data(xdata, ydata)
    return line,
def init():
    xdata, ydata = [], []
    line.set_data([], [])
    return line,

# %%
plt.ioff();
fig, ax = plt.subplots();
line, = ax.plot([], [], lw=2);
ax.set_xlim(0,10);
ax.set_ylim(0,10);
xdata, ydata = [], []
plt.ion();

# %%
ani = animation.FuncAnimation(fig, run,init_func=init,frames=range(1,15),interval=1,repeat=False)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
radius=470
turn_len=1484.5

# %%
# L = theta * pi * radius / 180

# %%
turn_len*180/(radius*np.pi)
# Out:
# 180.96932912163982

# %%
np.pi
# Out:
# 3.141592653589793
